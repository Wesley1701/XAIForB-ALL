# %%
import pandas as pd
import mygene

# %%
chunks = pd.read_csv(
        'GTEx_Analysis_v10_RNASeQCv2.4.2_gene_reads.gct',
        sep='\t',
        skiprows=2,         # Skip version and dimensions lines
        chunksize=1000
    )

# %%
df = chunks.get_chunk()
df
# Out:
#                    Name      Description  GTEX-1117F-0005-SM-HL9SH  \
# 0     ENSG00000223972.5          DDX11L1                         0
# 1     ENSG00000227232.5           WASH7P                        54
# 2     ENSG00000278267.1        MIR6859-1                         0
# 3     ENSG00000243485.5      MIR1302-2HG                         0
# 4     ENSG00000237613.2          FAM138A                         0
# ..                  ...              ...                       ...
# 995   ENSG00000215900.4        SELENOWP1                         0
# 996   ENSG00000225142.2  ENSG00000225142                         0
# 997  ENSG00000084628.10           NKAIN1                        18
# 998  ENSG00000060688.13          SNRNP40                       119
# 999   ENSG00000229447.2  ENSG00000229447                         0
#
#      GTEX-1117F-0011-R10b-SM-GI4VE  GTEX-1117F-0011-R11b-SM-GIN8R  \
# 0                                0                              0
# ...

# %%
# Get the gene
