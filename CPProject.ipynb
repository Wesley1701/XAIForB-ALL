# %% [markdown]
# # Explainable AI for B-ALL Subtype Classification Using RNA-Seq Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get all data

# %% [markdown]
# ### Generate the first rows

# %%
df = pd.read_csv('7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14.rna_seq.augmented_star_gene_counts.tsv', sep='\t', header=1, )

# Select the needed rows
df_firstrows = df.loc[4:, ['gene_id', 'gene_name', 'gene_type']]

# Flip the table
df_firstrows = df_firstrows.T

df_firstrows.columns = df_firstrows.iloc[0]  # Set the first row as the header
df_firstrows = df_firstrows[1:]  # Remove the first row now that it's the header
df_firstrows
# Out:
# gene_id   ENSG00000000003.15 ENSG00000000005.6 ENSG00000000419.13  \
# gene_name             TSPAN6              TNMD               DPM1
# gene_type     protein_coding    protein_coding     protein_coding
#
# gene_id   ENSG00000000457.14 ENSG00000000460.17 ENSG00000000938.13  \
# gene_name              SCYL3           C1orf112                FGR
# gene_type     protein_coding     protein_coding     protein_coding
#
# gene_id   ENSG00000000971.16 ENSG00000001036.14 ENSG00000001084.13  \
# gene_name                CFH              FUCA2               GCLC
# gene_type     protein_coding     protein_coding     protein_coding
#
# gene_id   ENSG00000001167.14  ... ENSG00000288661.1 ENSG00000288662.1  \
# gene_name               NFYA  ...        AL451106.1        AC092910.4
# gene_type     protein_coding  ...    protein_coding            lncRNA
#
# gene_id   ENSG00000288663.1 ENSG00000288665.1 ENSG00000288667.1  \
# gene_name        AC073611.1        AC136977.1        AC078856.1
# gene_type            lncRNA            lncRNA            lncRNA
#
# gene_id   ENSG00000288669.1 ENSG00000288670.1 ENSG00000288671.1  \
# gene_name        AC008763.4        AL592295.6        AC006486.3
# gene_type    protein_coding            lncRNA    protein_coding
#
# gene_id   ENSG00000288674.1 ENSG00000288675.1
# gene_name        AL391628.1        AP006621.6
# gene_type    protein_coding    protein_coding
#
# [2 rows x 60660 columns]

# %% [markdown]
# ### Populate all the rows

# %%
from pathlib import Path

# Set base directory
base_dir = Path.home() / 'Downloads' / 'GDC'

# Get all .tsv files recursively
tsv_files = list(base_dir.rglob('*.tsv'))

# List to hold individual dataframes
df_list = []

for file in tsv_files:
    df = pd.read_csv(file, sep='\t', header=1)
    
    # Select the needed rows
    df = df.loc[4:, ['gene_id', 'stranded_second']]
    
    # Flip the table
    df = df.T
    df.columns = df.iloc[0]  # Set the first row as the header
    df = df[1:]  # Remove the first row now that it's the header

    # Add an identifier for the file (e.g., file stem)
    df['sample_id'] = file.stem.split('.')[0]
    df_list.append(df)

# Combine all into one DataFrame
combined_df = pd.concat(df_list, ignore_index=True)

# Optionally set sample_id as index
combined_df.set_index('sample_id', inplace=True)

combined_df
# Out:
# gene_id                              ENSG00000000003.15 ENSG00000000005.6  \
# sample_id
# ee972b33-01e8-476a-ad1d-d75353333c43                  6                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                 18                 0
# 771ef539-368a-4523-bfbc-6f7fc96de534                 12                145
#
# gene_id                              ENSG00000001084.13 ENSG00000001167.14  \
# sample_id
# ee972b33-01e8-476a-ad1d-d75353333c43                478                524
# a063fd75-4ca6-468d-9134-86ff468fb1a8               1811               3548
# 4718568e-7816-4adf-96bd-7f5ad7944295                992               3706
# 4082cc4c-5c76-4f59-b7cf-e20e844485fa               1502               2314
# 7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14               3125               1794
# ...                                                 ...                ...
# fe9ca1c7-58be-4123-8742-68843ff9881b                929                680
# fff4dfba-2d68-4c05-9d1d-70f410afe6d4               1206                937
# c2f59459-f7e1-48ae-b1e0-7720085ca685                723               1381
# 571b4d3b-fce0-403b-a99c-2e58c338f70d                362               5076
# 771ef539-368a-4523-bfbc-6f7fc96de534               1397               3441
#
# gene_id                               ... ENSG00000288661.1 ENSG00000288662.1  \
# sample_id                             ...
# ee972b33-01e8-476a-ad1d-d75353333c43  ...                 0                11
# a063fd75-4ca6-468d-9134-86ff468fb1a8  ...                 0                 5
# 4718568e-7816-4adf-96bd-7f5ad7944295  ...                 0                13
# 4082cc4c-5c76-4f59-b7cf-e20e844485fa  ...                 0                 6
# 7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14  ...                 0                 5
# ...                                   ...               ...               ...
# fe9ca1c7-58be-4123-8742-68843ff9881b  ...                 0                11
# fff4dfba-2d68-4c05-9d1d-70f410afe6d4  ...                 0                 6
# c2f59459-f7e1-48ae-b1e0-7720085ca685  ...                 0                 7
# 571b4d3b-fce0-403b-a99c-2e58c338f70d  ...                 0                 0
# 771ef539-368a-4523-bfbc-6f7fc96de534  ...                 0                12
#
# gene_id                              ENSG00000288663.1 ENSG00000288665.1  \
# sample_id
# ee972b33-01e8-476a-ad1d-d75353333c43                25                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                23                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                50                 0
# 4082cc4c-5c76-4f59-b7cf-e20e844485fa                15                 0
# 7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14                14                 0
# ...                                                ...               ...
# fe9ca1c7-58be-4123-8742-68843ff9881b                26                 0
# fff4dfba-2d68-4c05-9d1d-70f410afe6d4                33                 0
# c2f59459-f7e1-48ae-b1e0-7720085ca685                16                 0
# 571b4d3b-fce0-403b-a99c-2e58c338f70d                96                 0
# 771ef539-368a-4523-bfbc-6f7fc96de534                14                 0
#
# gene_id                              ENSG00000288667.1 ENSG00000288669.1  \
# sample_id
# ee972b33-01e8-476a-ad1d-d75353333c43                 7                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                11                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                11                 0
# 4082cc4c-5c76-4f59-b7cf-e20e844485fa                 1                 0
# 7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14                 0                 0
# ...                                                ...               ...
# fe9ca1c7-58be-4123-8742-68843ff9881b                 4                 0
# fff4dfba-2d68-4c05-9d1d-70f410afe6d4                12                 0
# c2f59459-f7e1-48ae-b1e0-7720085ca685                17                 1
# 571b4d3b-fce0-403b-a99c-2e58c338f70d               109                 0
# 771ef539-368a-4523-bfbc-6f7fc96de534                 9                 0
#
# gene_id                              ENSG00000288670.1 ENSG00000288671.1  \
# sample_id
# ee972b33-01e8-476a-ad1d-d75353333c43                48                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                39                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                71                 0
# 4082cc4c-5c76-4f59-b7cf-e20e844485fa                37                 0
# 7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14                50                 0
# ...                                                ...               ...
# fe9ca1c7-58be-4123-8742-68843ff9881b                31                 0
# fff4dfba-2d68-4c05-9d1d-70f410afe6d4                31                 0
# c2f59459-f7e1-48ae-b1e0-7720085ca685                34                 0
# 571b4d3b-fce0-403b-a99c-2e58c338f70d                 0                 0
# 771ef539-368a-4523-bfbc-6f7fc96de534                86                 0
#
# gene_id                              ENSG00000288674.1 ENSG00000288675.1
# sample_id
# ee972b33-01e8-476a-ad1d-d75353333c43                 0                14
# a063fd75-4ca6-468d-9134-86ff468fb1a8                 1                26
# 4718568e-7816-4adf-96bd-7f5ad7944295                 0                26
# 4082cc4c-5c76-4f59-b7cf-e20e844485fa                 4                16
# 7e8776a3-a56c-4ebc-a32b-d8cb7b7cea14                 5                34
# ...                                                ...               ...
# fe9ca1c7-58be-4123-8742-68843ff9881b                 5                23
# fff4dfba-2d68-4c05-9d1d-70f410afe6d4                 1                49
# c2f59459-f7e1-48ae-b1e0-7720085ca685                 0                30
# 571b4d3b-fce0-403b-a99c-2e58c338f70d                 0                 8
# 771ef539-368a-4523-bfbc-6f7fc96de534                 6                20
#
# [895 rows x 60660 columns]

# %% [markdown]
# ### Create full table

# %%
final_df = pd.concat([df_firstrows, combined_df], ignore_index=False)
final_df.head(5)
# Out:
# gene_id                              ENSG00000000003.15 ENSG00000000005.6  \
# gene_name                                        TSPAN6              TNMD
# gene_type                                protein_coding    protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                  6                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                 18                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                  5                 0
#
# gene_id                              ENSG00000000419.13 ENSG00000000457.14  \
# gene_name                                          DPM1              SCYL3
# gene_type                                protein_coding     protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43               1702                266
# a063fd75-4ca6-468d-9134-86ff468fb1a8                896                574
# 4718568e-7816-4adf-96bd-7f5ad7944295               1690                329
#
# gene_id                              ENSG00000000460.17 ENSG00000000938.13  \
# gene_name                                      C1orf112                FGR
# gene_type                                protein_coding     protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                139                125
# a063fd75-4ca6-468d-9134-86ff468fb1a8                572                501
# 4718568e-7816-4adf-96bd-7f5ad7944295                245                102
#
# gene_id                              ENSG00000000971.16 ENSG00000001036.14  \
# gene_name                                           CFH              FUCA2
# gene_type                                protein_coding     protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                 16                 14
# a063fd75-4ca6-468d-9134-86ff468fb1a8                 37                109
# 4718568e-7816-4adf-96bd-7f5ad7944295                  6                 13
#
# gene_id                              ENSG00000001084.13 ENSG00000001167.14  \
# gene_name                                          GCLC               NFYA
# gene_type                                protein_coding     protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                478                524
# a063fd75-4ca6-468d-9134-86ff468fb1a8               1811               3548
# 4718568e-7816-4adf-96bd-7f5ad7944295                992               3706
#
# gene_id                               ... ENSG00000288661.1 ENSG00000288662.1  \
# gene_name                             ...        AL451106.1        AC092910.4
# gene_type                             ...    protein_coding            lncRNA
# ee972b33-01e8-476a-ad1d-d75353333c43  ...                 0                11
# a063fd75-4ca6-468d-9134-86ff468fb1a8  ...                 0                 5
# 4718568e-7816-4adf-96bd-7f5ad7944295  ...                 0                13
#
# gene_id                              ENSG00000288663.1 ENSG00000288665.1  \
# gene_name                                   AC073611.1        AC136977.1
# gene_type                                       lncRNA            lncRNA
# ee972b33-01e8-476a-ad1d-d75353333c43                25                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                23                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                50                 0
#
# gene_id                              ENSG00000288667.1 ENSG00000288669.1  \
# gene_name                                   AC078856.1        AC008763.4
# gene_type                                       lncRNA    protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                 7                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                11                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                11                 0
#
# gene_id                              ENSG00000288670.1 ENSG00000288671.1  \
# gene_name                                   AL592295.6        AC006486.3
# gene_type                                       lncRNA    protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                48                 0
# a063fd75-4ca6-468d-9134-86ff468fb1a8                39                 0
# 4718568e-7816-4adf-96bd-7f5ad7944295                71                 0
#
# gene_id                              ENSG00000288674.1 ENSG00000288675.1
# gene_name                                   AL391628.1        AP006621.6
# gene_type                               protein_coding    protein_coding
# ee972b33-01e8-476a-ad1d-d75353333c43                 0                14
# a063fd75-4ca6-468d-9134-86ff468fb1a8                 1                26
# 4718568e-7816-4adf-96bd-7f5ad7944295                 0                26
#
# [5 rows x 60660 columns]

# %%
final_df.to_csv('rna_seq_stranded_second.csv')
